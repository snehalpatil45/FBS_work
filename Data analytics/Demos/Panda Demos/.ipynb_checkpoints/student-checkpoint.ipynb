# %%
import pandas as pd
import numpy as np

# %%
students = [f"Student_{i}" for i in range(1, 31)]

subjects = ["Physics", "Chemistry", "Biology","Mathematics","Geography", "English"]

marks = np.random.randint(30, 100,(30, 6))

df = pd.DataFrame(marks, columns=subjects)

df.insert(0, "Student_Name", students)

df["Total"] = df[subjects].sum(axis=1)

df["Percentage"] = (df["Total"] / 600) * 100

print(df)
# Out:
#    Student_Name  Maths  Science  English  Physics  Chemistry  Computer  Total  \
# 0     Student_1     82       77       46       49         93        81    428
# 1     Student_2     33       55       92       42         37        75    334
# 2     Student_3     65       73       89       47         32        99    405
# 3     Student_4     95       42       35       33         42        54    301
# 4     Student_5     94       97       69       75         45        35    415
# 5     Student_6     68       97       99       74         52        62    452
# 6     Student_7     94       83       94       60         32        33    396
# 7     Student_8     34       63       81       96         38        31    343
# 8     Student_9     48       72       69       62         38        58    347
# 9    Student_10     56       61       43       35         31        97    323
# 10   Student_11     63       98       69       53         91        93    467
# 11   Student_12     74       53       30       85         87        46    375
# 12   Student_13     47       81       71       42         42        35    318
# 13   Student_14     80       32       50       80         96        65    403
# 14   Student_15     82       79       77       90         80        58    466
# 15   Student_16     89       36       49       97         64        59    394
# 16   Student_17     61       30       88       52         45        46    322
# 17   Student_18     68       74       46       41         57        37    323
# 18   Student_19     84       43       55       80         86        52    400
# 19   Student_20     56       78       34       74         85        35    362
# 20   Student_21     83       52       40       69         31        74    349
# 21   Student_22     52       70       34       71         53        34    314
# 22   Student_23     41       30       68       33         41        64    277
# 23   Student_24     75       83       68       49         85        93    453
# 24   Student_25     64       67       89       72         67        97    456
# 25   Student_26     86       50       70       77         67        93    443
# 26   Student_27     36       73       77       91         87        91    455
# 27   Student_28     64       37       64       97         87        76    425
# 28   Student_29     52       67       58       55         60        97    389
# 29   Student_30     97       67       44       53         35        86    382
#
#     Percentage
# 0    71.333333
# 1    55.666667
# 2    67.500000
# 3    50.166667
# 4    69.166667
# 5    75.333333
# 6    66.000000
# 7    57.166667
# 8    57.833333
# 9    53.833333
# 10   77.833333
# 11   62.500000
# 12   53.000000
# 13   67.166667
# 14   77.666667
# 15   65.666667
# 16   53.666667
# 17   53.833333
# 18   66.666667
# 19   60.333333
# 20   58.166667
# 21   52.333333
# 22   46.166667
# 23   75.500000
# 24   76.000000
# 25   73.833333
# 26   75.833333
# 27   70.833333
# 28   64.833333
# 29   63.666667
