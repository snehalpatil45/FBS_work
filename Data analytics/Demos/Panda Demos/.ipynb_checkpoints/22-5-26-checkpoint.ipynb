# %%
import pandas as pd

# %%
emp = pd.DataFrame({'Name':['Akshay', 'Rohit', 'Virat', 'John', 'Michael'],
                   'Age':[32, 45, 28, 32, 27],
                   'Salary':[45000, 38000, 29000, 50000, 41000],
                   })
emp
# Out:
#       Name  Age  Salary  DID
# 0   Akshay   32   45000    1
# 1    Rohit   45   38000    2
# 2    Virat   28   29000    2
# 3     John   32   50000    3
# 4  Michael   27   41000    4

# %%
emp['Salary'].mean()
# Out:
# np.float64(40600.0)

# %%
emp['Salary'].median()
# Out:
# np.float64(41000.0)

# %%
emp['Salary'].mode()
# Out:
# 0    29000
# 1    38000
# 2    41000
# 3    45000
# 4    50000
# Name: Salary, dtype: int64

# %%
emp['Age'].mode()
# Out:
# 0    32
# Name: Age, dtype: int64

# %%
emp['Name'].mode()
# Out:
# 0     Akshay
# 1       John
# 2    Michael
# 3      Rohit
# 4      Virat
# Name: Name, dtype: str

# %%
emp['Age'].unique()
# Out:
# array([32, 45, 28, 27])

# %%
emp['Name'].unique()
# Out:
# <StringArray>
# ['Akshay', 'Rohit', 'Virat', 'John', 'Michael']
# Length: 5, dtype: str

# %%
emp['Age'].value_counts()
# Out:
# Age
# 32    2
# 45    1
# 28    1
# 27    1
# Name: count, dtype: int64

# %%
emp['Name'].value_counts()
# Out:
# Name
# Akshay     1
# Rohit      1
# Virat      1
# John       1
# Michael    1
# Name: count, dtype: int64

# %%
iris = pd.read_csv('Datasets/Iris.csv')
iris.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris['Species'].value_counts()
# Out:
# Species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
iris['Species'].unique()
# Out:
# <StringArray>
# ['Setosa', 'Versicolor', 'Virginica']
# Length: 3, dtype: str

# %% [markdown]
# #create dataset for students with random marks (30 student,6 subjects).calculate total marks and percentage for every student.

# %%
emp['DID'] = [1, 2, 2, 3, 4]
emp
# Out:
#       Name  Age  Salary  DID
# 0   Akshay   32   45000    1
# 1    Rohit   45   38000    2
# 2    Virat   28   29000    2
# 3     John   32   50000    3
# 4  Michael   27   41000    4

# %%
emp['DID'] = [3, 2, 2, 1, 4]
emp
# Out:
#       Name  Age  Salary  DID
# 0   Akshay   32   45000    3
# 1    Rohit   45   38000    2
# 2    Virat   28   29000    2
# 3     John   32   50000    1
# 4  Michael   27   41000    4

# %%
emp.insert(2,value = ['Pune','Mumbai','CSN','Nashik','Dharashiv'],column = 'Address')
emp
# Out:
#       Name  Age    Address  Salary  DID
# 0   Akshay   32       Pune   45000    3
# 1    Rohit   45     Mumbai   38000    2
# 2    Virat   28        CSN   29000    2
# 3     John   32     Nashik   50000    1
# 4  Michael   27  Dharashiv   41000    4

# %%
emp.loc[len(emp)] = ['Roshan',67,'pune',100000,1]
emp
# Out:
#       Name  Age    Address  Salary  DID
# 0   Akshay   32       Pune   45000    3
# 1    Rohit   45     Mumbai   38000    2
# 2    Virat   28        CSN   29000    2
# 3     John   32     Nashik   50000    1
# 4  Michael   27  Dharashiv   41000    4
# 5   Roshan   67       pune  100000    1

# %%
#emp = emp.drop(10)
emp.drop(10,inplace= True)

# %%
emp
# Out:
#       Name  Age    Address  Salary  DID
# 0   Akshay   32       Pune   45000    3
# 1    Rohit   45     Mumbai   38000    2
# 2    Virat   28        CSN   29000    2
# 3     John   32     Nashik   50000    1
# 4  Michael   27  Dharashiv   41000    4
# 5   Roshan   67       pune  100000    1

# %%
emp.loc[emp['Name'] == 'John']
# Out:
#    Name  Age Address  Salary  DID
# 3  John   32  Nashik   50000    1

# %%
emp.loc[emp['Name'] == 'Rohit'] = 90000
emp
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 emp.loc[emp['Name'] == 'Rohit'] = 90000
#       2 emp
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:938, in _LocationIndexer.__setitem__(self, key, value)
#     933 self._has_valid_setitem_indexer(key)
#     935 iloc: _iLocIndexer = (
#     936     cast("_iLocIndexer", self) if self.name == "iloc" else self.obj.iloc
#     937 )
# --> 938 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1953, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1950 # align and set the values
#    1951 if take_split_path:
#    1952     # We have to operate column-wise
# -> 1953     self._setitem_with_indexer_split_path(indexer, value, name)
#    1954 else:
# ...
