# %%
import numpy as np

# %%
np.sin(np.radians(90))
# Out:
# np.float64(1.0)

# %%
np.cos(np.radians(90))
# Out:
# np.float64(6.123233995736766e-17)

# %%
np.tan(np.radians(90))
# Out:
# np.float64(1.633123935319537e+16)

# %% [markdown]
# ###### 1.53e-2 = 0.0153 ###### 1.5372e+2 = 153.72
