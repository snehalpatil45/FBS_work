# %% [markdown]
# #### Numpy
# 1.scientific computing liabrary - numeric python
# 2. Build with python + c
# 3. used for multi dimension array,matrix
# 4. used for mathematical calculations

# %% [markdown]
# ### Numpy Array vs Python List

# %% [markdown]
# ##### speed

# %%
# %%time

li1 = list(range(1,100001))
li2 = list(range(2,100002))
li3 = []
for i in range(len(li1)):
    li3.append(li1[i] + li2[i])
# Out:
# CPU times: total: 31.2 ms
# Wall time: 17.9 ms

# %%
import numpy as np

# %%
# %%time
arr1 = np.arange(1,100001)
arr2 = np.arange(2,100002)
arr1 + arr2
# Out:
# CPU times: total: 0 ns
# Wall time: 708 μs
# array([     3,      5,      7, ..., 199997, 199999, 200001],
#       shape=(100000,))
