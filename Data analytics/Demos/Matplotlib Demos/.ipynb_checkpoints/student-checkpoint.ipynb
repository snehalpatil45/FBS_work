# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("C:/Users/ASUS/Desktop/FBS/Data analytics/Demos/Panda Demos/student_marks.xlsx")
print(df.head())
# Out:
#   Student_Name  Physics  Chemistry  Biology  Mathematics  Geography  English  \
# 0    Student_1       58         49       91           79         38       53
# 1    Student_2       60         73       70           49         55       50
# 2    Student_3       96         98       74           48         47       62
# 3    Student_4       92         95       71           43         48       56
# 4    Student_5       79         76       32           40         62       95
#
#    Total  Percentage
# 0    368   61.333333
# 1    357   59.500000
# 2    425   70.833333
# 3    405   67.500000
# 4    384   64.000000

# %%
plt.figure(figsize=(12,6))
plt.bar(df["Student_Name"], df["Percentage"])
plt.xlabel("Students")
plt.ylabel("Percentage")
plt.title("Student Percentage Analysis")
plt.show()
