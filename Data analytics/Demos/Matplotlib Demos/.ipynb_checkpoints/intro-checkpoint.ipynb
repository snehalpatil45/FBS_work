# %% [markdown]
# ##### Matplotlib
# 1. 2D and 3D plotting python library
# 2. High quality graphs.
# 3. It supports animationn.

# %% [markdown]
# #### Matplotlib graphs
# 1. Histrogram
# 2. Barplot
# 3. Lineplot
# 4. Scatterplot
# 5. Pie chart
# 6. Donut plot
# 7. Waterfall plot
# 8. Error plot
# 9. Power spectrum
